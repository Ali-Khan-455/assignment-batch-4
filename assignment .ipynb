# %%
def table(_from , _to):
    for i in range(_from,_to+1):
      print("\n")
      for x in range(1,10):
        print("\t")
        print(str(x) + " * " + str(i) + " = " + str(x*i))

table(5,10)
# Out:
#
# 1 * 5 = 5
#
# 2 * 5 = 10
#
# 3 * 5 = 15
#
# 4 * 5 = 20
#
# 5 * 5 = 25
#
# 6 * 5 = 30
#
# 7 * 5 = 35
#
# 8 * 5 = 40
#
# 9 * 5 = 45
#
#
#
# 1 * 6 = 6
#
# 2 * 6 = 12
#
# 3 * 6 = 18
#
# 4 * 6 = 24
#
# 5 * 6 = 30
#
# 6 * 6 = 36
#
# 7 * 6 = 42
#
# 8 * 6 = 48
#
# 9 * 6 = 54
#
#
#
# 1 * 7 = 7
#
# 2 * 7 = 14
#
# 3 * 7 = 21
#
# 4 * 7 = 28
#
# 5 * 7 = 35
#
# 6 * 7 = 42
#
# 7 * 7 = 49
#
# 8 * 7 = 56
#
# 9 * 7 = 63
#
#
#
# 1 * 8 = 8
#
# 2 * 8 = 16
#
# 3 * 8 = 24
#
# 4 * 8 = 32
#
# 5 * 8 = 40
#
# 6 * 8 = 48
#
# 7 * 8 = 56
#
# 8 * 8 = 64
#
# 9 * 8 = 72
#
#
#
# 1 * 9 = 9
#
# 2 * 9 = 18
#
# 3 * 9 = 27
#
# 4 * 9 = 36
#
# 5 * 9 = 45
#
# 6 * 9 = 54
#
# 7 * 9 = 63
#
# 8 * 9 = 72
#
# 9 * 9 = 81
#
#
#
# 1 * 10 = 10
#
# 2 * 10 = 20
#
# 3 * 10 = 30
#
# 4 * 10 = 40
#
# 5 * 10 = 50
#
# 6 * 10 = 60
#
# 7 * 10 = 70
#
# 8 * 10 = 80
#
# 9 * 10 = 90

# %%
def User_Data(_name,_age,_work,_skills,_degree,_salary):
    user_dict = {"Name"   : _name,
                 "Age"    : _age,
                 "work"   : _work,
                 "Skills" : _skills,
                 "Degree" : _degree,
                 "Salary" : _salary
                 }
    return user_dict

listes = []

u1 = User_Data("ali",23,"Developer","software ","BSCS",50000)
u2 = User_Data("hamza",22,"teacher","Pythanist","BSCS",70000)
u3 = User_Data("Shan",24,"head of department","eng","BSClishS",100000)

listes.append(u1)
listes.append(u2)
listes.append(u3)

print(listes)
# Out:
# [{'Name': 'ali', 'Age': 23, 'work': 'Developer', 'Skills': 'software ', 'Degree': 'BSCS', 'Salary': 50000}, {'Name': 'hamza', 'Age': 22, 'work': 'teacher', 'Skills': 'Pythanist', 'Degree': 'BSCS', 'Salary': 70000}, {'Name': 'Shan', 'Age': 24, 'work': 'head of department', 'Skills': 'eng', 'Degree': 'BSClishS', 'Salary': 100000}]
